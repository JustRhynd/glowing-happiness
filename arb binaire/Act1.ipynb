# %% [markdown]
# # Activité 1

# %% [markdown]
# On donne le code suivant :

# %%
class Node:
    """ un noeud de la classe Node contient trois attributs : 
    - valeur (qui est passé en paramètre : v)
    - gauche et droit qui sont des arbres binaires vides, instances de la classe ABR"""
    def __init__(self, v):
        self.gauche = ABR()
        self.valeur = v        
        self.droit  = ABR()

class ABR:
    def __init__(self):
        self.racine = None # arbre vide
        # si self n'est pas vide, alors self.racine est une instance de la classe Node
 
    def insere(self, val):
        ''' val est une valeur du même type que les valeurs déjà présentes dans self
        la fonction insers val en conservant l'ordre '''
        if self.racine is None : 
            self.racine = Node(val)
        elif val < self.racine.valeur : 
            self.racine.gauche.insere(val)
        else :
            self.racine.droit.insere(val)

# %% [markdown]
# Représenter schématiquement le contenu de la variable `a` lorsqu'on exécute chacune des commandes suivantes.

# %%
a = ABR()
a.insere(100)
a.insere(50)
a.insere(40)
a.insere(60)

# %% [markdown]
# Vérifier ensuite avec [PythonTutor](https://pythontutor.com/render.html#code=class%20Node%3A%0A%20%20%20%20%22%22%22%20un%20noeud%20de%20la%20classe%20Node%20contient%20trois%20attributs%20%3A%20%0A%20%20%20%20-%20valeur%20%28qui%20est%20pass%C3%A9%20en%20param%C3%A8tre%20%3A%20v%29%0A%20%20%20%20-%20gauche%20et%20droit%20qui%20sont%20des%20arbres%20binaires%20vides,%20instances%20de%20la%20classe%20ABR%22%22%22%0A%20%20%20%20def%20__init__%28self,%20v%29%3A%0A%20%20%20%20%20%20%20%20self.gauche%20%3D%20ABR%28%29%0A%20%20%20%20%20%20%20%20self.valeur%20%3D%20v%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20self.droit%20%20%3D%20ABR%28%29%0A%0Aclass%20ABR%3A%0A%20%20%20%20def%20__init__%28self%29%3A%0A%20%20%20%20%20%20%20%20self.racine%20%3D%20None%20%23%20arbre%20vide%0A%20%20%20%20%20%20%20%20%23%20si%20self%20n'est%20pas%20vide,%20alors%20self.racine%20est%20une%20instance%20de%20la%20classe%20Node%0A%0A%20%20%20%20def%20insere%28self,%20val%29%3A%0A%20%20%20%20%20%20%20%20'''%20val%20est%20une%20valeur%20du%20m%C3%AAme%20type%20que%20les%20valeurs%20d%C3%A9j%C3%A0%20pr%C3%A9sentes%20dans%20self%0A%20%20%20%20%20%20%20%20la%20fonction%20insers%20val%20en%20conservant%20l'ordre%20'''%0A%20%20%20%20%20%20%20%20if%20self.racine%20is%20None%20%3A%20%0A%20%20%20%20%20%20%20%20%20%20%20%20self.racine%20%3D%20Node%28val%29%0A%20%20%20%20%20%20%20%20elif%20val%20%3C%20self.racine.valeur%20%3A%20%0A%20%20%20%20%20%20%20%20%20%20%20%20self.racine.gauche.insere%28val%29%0A%20%20%20%20%20%20%20%20else%20%3A%0A%20%20%20%20%20%20%20%20%20%20%20%20self.racine.droit.insere%28val%29%0A%0Aa%20%3D%20ABR%28%29%0Aa.insere%28100%29%0Aa.insere%2850%29%0Aa.insere%2840%29%0Aa.insere%2860%29&cumulative=false&curInstr=6&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)

# %% [markdown]
# que se passe-t-il si on exécute :

# %%
b = ABR()
b.insere(50)
b.insere(100)
b.insere(40)
b.insere(60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 b = ABR()
#       2 b.insere(50)
#       3 b.insere(100)
#
# NameError: name 'ABR' is not defined

# %%
print = 1

# %%
print
# Out:
# 1
